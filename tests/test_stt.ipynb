# %%
import asyncio
import websockets
import json
import time
import pandas as pd
import jiwer
from tqdm.asyncio import tqdm

WS_URL = "ws://127.0.0.1:8000/api/v1/ws"

# %%
# --- 평가 지표 함수 ---
def normalize(text):
    transformation = jiwer.Compose([
        jiwer.ToLowerCase(),
        jiwer.RemovePunctuation(),
        jiwer.RemoveMultipleSpaces(),
        jiwer.Strip(),
    ])
    return transformation(text)

def calculate_metrics(truth, hypothesis):
    norm_truth = normalize(truth)
    norm_hyp = normalize(hypothesis)
    if not norm_truth: return 0.0, 0.0
    
    wer = jiwer.wer(norm_truth, norm_hyp)
    cer = jiwer.cer(norm_truth, norm_hyp)
    return wer, cer

# %%
import os
import glob

BASE_DIR = r"C:\backend\tests\test_dataset"
WAV_ROOT = os.path.join(BASE_DIR, "wav")
LABEL_ROOT = os.path.join(BASE_DIR, "label")

def load_dataset_separated(wav_root, label_root):
    dataset = []
    
    search_pattern = os.path.join(wav_root, "**", "*.wav")
    wav_files = glob.glob(search_pattern, recursive=True)
    
    print(f"검색된 WAV 파일 수: {len(wav_files)}")

    for wav_path in wav_files:
        rel_path = os.path.relpath(wav_path, wav_root)
        
        rel_txt_path = rel_path.replace(".wav", ".txt").replace(".WAV", ".txt")
        target_txt_path = os.path.join(label_root, rel_txt_path)
        
        if os.path.exists(target_txt_path):
            try:
                with open(target_txt_path, 'r', encoding='utf-8') as f:
                    ground_truth = f.read().strip()
            except UnicodeDecodeError:
                with open(target_txt_path, 'r', encoding='cp949') as f:
                    ground_truth = f.read().strip()

            folder_name = os.path.dirname(rel_path) # S00000365
            file_name = os.path.basename(wav_path)  # 0001.wav
            
            unique_id = f"{folder_name}_{file_name}"
            
            dataset.append({
                "id": unique_id,           # 고유 식별자
                "folder": folder_name,     # 폴더 정보
                "audio_path": wav_path,    # 실제 경로
                "truth": ground_truth      # 정답
            })
        else:
            pass

    return dataset

# 실행
data = load_dataset_separated(WAV_ROOT, LABEL_ROOT)
# Out:
# 검색된 WAV 파일 수: 321

# %%
print(data)
# Out:
# [{'id': 'S00000365_0001.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0001.wav', 'truth': '네 고객님 중앙교육의 이진혁 상담원입니다.'}, {'id': 'S00000365_0002.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0002.wav', 'truth': '네 안녕하세요. 결제 때문에 전화 드렸어요.'}, {'id': 'S00000365_0003.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0003.wav', 'truth': 'n/ 어/ 분당 살 때'}, {'id': 'S00000365_0004.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0004.wav', 'truth': '중앙교육 학습지 몇 년 했었고요.'}, {'id': 'S00000365_0005.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0005.wav', 'truth': '지금은 학습지 이용 안 하고 있거든요. 그리고 저희 서초로 이사도 했고요.'}, {'id': 'S00000365_0006.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0006.wav', 'truth': '근데 며칠 전에 갑자기 여기 학습지 결제 문자가 뜨더라고요. (18)/(십팔)만 원이 결제를 됐는데 저희 지금 여기서 학습지 이용 안 하고 있어요. 어떻게 된 건가요?'}, {'id': 'S00000365_0007.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0007.wav', 'truth': '알아보겠습니다.'}, {'id': 'S00000365_0008.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0008.wav', 'truth': '네 빨리 좀 알아봐 주세요. 그때 분명히 선생님하고도 잘 인사했고 마치고 끝냈는데 갑자기 결제 문자 와서 놀랬거든요.'}, {'id': 'S00000365_0009.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0009.wav', 'truth': '네 알아본 결과 학습 종료가 안 된 걸로 나와있습니다.'}, {'id': 'S00000365_0010.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0010.wav', 'truth': '학습이 종료 안됐다고요?'}, {'id': 'S00000365_0011.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0011.wav', 'truth': '아/ 저희 저번에 분명히 끝내고 이사까지 했는데요.'}, {'id': 'S00000365_0012.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0012.wav', 'truth': '죄송합니다.'}, {'id': 'S00000365_0013.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0013.wav', 'truth': '아니 선생님하고 어떻게 이야기가 됐길래 학습 종료가 안 돼요?'}, {'id': 'S00000365_0014.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0014.wav', 'truth': '알아보고 처리해 드리겠습니다.'}, {'id': 'S00000365_0015.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0015.wav', 'truth': '처리해 주는 건 당연하고요. 그것보다 저희 카드번호도 분명히 개인 정보인데 해제하면 삭제해야 되는 거 아닌가요?'}, {'id': 'S00000365_0016.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0016.wav', 'truth': '예전에 저희 학습지 할 때도 결제금액 이상해서 고객센터에 문의해보니까 저희가 하지도 않은 과목을 등록시켜서 그게 (둘)/(두) 달 분이나 결제됐더라고요.'}, {'id': 'S00000365_0017.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0017.wav', 'truth': '그러셨군요.'}, {'id': 'S00000365_0018.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0018.wav', 'truth': '저희가 알았으니까 망정이지 몰랐으면 그렇게 남의 계좌에서 돈을 계속 빼 갔을 거 아니에요. 통지 같은 것도 안 해주고.'}, {'id': 'S00000365_0019.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0019.wav', 'truth': '죄송합니다.'}, {'id': 'S00000365_0020.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0020.wav', 'truth': '그때는 이제 애가 여기 선생님도 좋아하고 학습지도 마음에 들어하고 있어서 그냥 넘겼거든요.'}, {'id': 'S00000365_0021.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0021.wav', 'truth': '남편은 이런 거 그냥 넘기면 안 된다고 했지만 애가 잘하고 있는데 괜히 선생님 불편하게 만들어서 좋을 거 없으니까'}, {'id': 'S00000365_0022.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_dataset\\wav\\S00000365\\0022.wav', 'truth': '근데 저희는 분명히 그만뒀는데 결제하는 건 좀 아니잖아요.'}, {'id': 'S00000365_0023.wav', 'folder': 'S00000365', 'audio_path': 'C:\\backend\\tests\\test_da ...

# %%
import asyncio
import websockets
import json
import time
import wave
import contextlib
import pandas as pd
from tqdm.asyncio import tqdm

async def process_single_item(websocket, file_item):
    audio_path = file_item['audio_path'] 
    ground_truth = file_item['truth']
    
    # 오디오 파일 읽기
    with open(audio_path, "rb") as f:
        audio_bytes = f.read()
        
    # 오디오 길이 계산
    with contextlib.closing(wave.open(audio_path, 'r')) as f:
        frames = f.getnframes()
        rate = f.getframerate()
        audio_duration = frames / float(rate)

    result_data = {
        "file": file_item['id'],
        "duration": audio_duration,
        "latency": None,
        "rtf": None,              
        "wer": None,
        "cer": None,
        "truth": ground_truth,
        "hypothesis": "",
        "status": "fail",
        "error_msg": ""
    }

    try:
        start_time = time.perf_counter()
        
        await websocket.send(audio_bytes)
        
        # 응답 대기 (30초 타임아웃)
        response = await asyncio.wait_for(websocket.recv(), timeout=30.0)
        end_time = time.perf_counter()
        
        # 결과 파싱
        resp_json = json.loads(response)
        
        if isinstance(resp_json, dict):
            hypothesis = resp_json.get("text", "")
        else:
            hypothesis = str(resp_json)
        
        # 지표 계산
        wer, cer = calculate_metrics(ground_truth, hypothesis)
        latency = end_time - start_time
        rtf = latency / audio_duration if audio_duration > 0 else 0
        
        result_data.update({
            "latency": latency,
            "rtf": rtf,
            "wer": wer,
            "cer": cer,
            "hypothesis": hypothesis,
            "status": "success"
        })
        
    except Exception as e:
        print(f"에러 ({file_item['id']}): {e}")
        result_data["error_msg"] = str(e)
        
    return result_data

# %%
# --- 배치 실행 함수 ---
async def run_batch_test(dataset):
    results = []
    
    try:
        async with websockets.connect(WS_URL, ping_interval=None) as websocket:
            print("연결 성공")
            
            # tqdm으로 진행 상황 표시
            for item in tqdm(dataset):
                # 연결된 websocket 객체를 인자로 넘김
                res = await process_single_item(websocket, item)
                results.append(res)
                
    except Exception as e:
        print(f"에러 : {e}")
        
    return results

# %%
# --- 실행 및 분석 ---
results = await run_batch_test(data)
# Out:
# 연결 성공
# 100%|██████████| 321/321 [06:38<00:00,  1.24s/it]

# %%
print(results)
# Out:
# [{'file': 'S00000365_0001.wav', 'duration': 4.10725, 'latency': 1.0202085000055376, 'rtf': 0.2483921115114828, 'wer': 0.0, 'cer': 0.0, 'truth': '네 고객님 중앙교육의 이진혁 상담원입니다.', 'hypothesis': '네, 고객님. 중앙교육의 이진혁 상담원입니다.', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0002.wav', 'duration': 3.157375, 'latency': 1.439488399977563, 'rtf': 0.45591302901225317, 'wer': 0.5, 'cer': 0.09090909090909091, 'truth': '네 안녕하세요. 결제 때문에 전화 드렸어요.', 'hypothesis': '예, 안녕하세요. 결제 때문에 전화드렸어요.', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0003.wav', 'duration': 1.690375, 'latency': 1.4824691000103485, 'rtf': 0.8770060489597565, 'wer': 0.4, 'cer': 0.4, 'truth': 'n/ 어/ 분당 살 때', 'hypothesis': '분당 살 때', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0004.wav', 'duration': 2.7, 'latency': 0.9068489000201225, 'rtf': 0.3358699629704157, 'wer': 0.4, 'cer': 0.058823529411764705, 'truth': '중앙교육 학습지 몇 년 했었고요.', 'hypothesis': '중앙교육학습지 몇 년 했었고요.', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0005.wav', 'duration': 5.19, 'latency': 0.866270300000906, 'rtf': 0.16691142581905702, 'wer': 0.18181818181818182, 'cer': 0.05128205128205128, 'truth': '지금은 학습지 이용 안 하고 있거든요. 그리고 저희 서초로 이사도 했고요.', 'hypothesis': '지금은 학습지 이용 안 하고 있거든요. 그리고 저희 서초로 이사 또 했고요.', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0006.wav', 'duration': 11.221375, 'latency': 1.32638029998634, 'rtf': 0.11820122756670551, 'wer': 0.16666666666666666, 'cer': 0.07058823529411765, 'truth': '근데 며칠 전에 갑자기 여기 학습지 결제 문자가 뜨더라고요. (18)/(십팔)만 원이 결제를 됐는데 저희 지금 여기서 학습지 이용 안 하고 있어요. 어떻게 된 건가요?', 'hypothesis': '그런데 며칠 전에 갑자기 여기 학습지 결제 문자가 뜨더라고요. 18만 원이 결제됐는데 저희 지금 여기서 학습지 이용 안 하고 있어요. 어떻게 된 건가요?', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0007.wav', 'duration': 1.77175, 'latency': 1.3500819000182673, 'rtf': 0.7620047410855185, 'wer': 0.0, 'cer': 0.0, 'truth': '알아보겠습니다.', 'hypothesis': '알아보겠습니다.', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0008.wav', 'duration': 9.72, 'latency': 2.3644777000008617, 'rtf': 0.24325902263383348, 'wer': 0.35294117647058826, 'cer': 0.09523809523809523, 'truth': '네 빨리 좀 알아봐 주세요. 그때 분명히 선생님하고도 잘 인사했고 마치고 끝냈는데 갑자기 결제 문자 와서 놀랬거든요.', 'hypothesis': '그런데 빨리 좀 알아봐주세요. 그때 분명히 선생님하고도 잘 인사했고, 마치고 끝냈는데 갑자기 결제 문자와서 놀랐거든요.', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0009.wav', 'duration': 4.010625, 'latency': 1.5410372999904212, 'rtf': 0.3842386909747037, 'wer': 0.2222222222222222, 'cer': 0.034482758620689655, 'truth': '네 알아본 결과 학습 종료가 안 된 걸로 나와있습니다.', 'hypothesis': '네, 알아본 결과 학습 종료가 안 된 걸로 나와 있습니다.', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0010.wav', 'duration': 2.048, 'latency': 0.633178800024325, 'rtf': 0.30916933594937746, 'wer': 0.6666666666666666, 'cer': 0.08333333333333333, 'truth': '학습이 종료 안됐다고요?', 'hypothesis': '학습이 종료 안 됐다고요?', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0011.wav', 'duration': 3.797375, 'latency': 0.8712199000001419, 'rtf': 0.22942688041084747, 'wer': 0.0, 'cer': 0.0, 'truth': '아/ 저희 저번에 분명히 끝내고 이사까지 했는데요.', 'hypothesis': '아 저희 저번에 분명히 끝내고 이사까지 했는데요', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0012.wav', 'duration': 2.090625, 'latency': 0.5824345000146423, 'rtf': 0.27859348281716817, 'wer': 0.0, 'cer': 0.0, 'truth': '죄송합니다.', 'hypothesis': '죄송합니다.', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0013.wav', 'duration': 4.954375, 'latency': 1.6146333999931812, 'rtf': 0.325900522264298, 'wer': 0.0, 'cer': 0.0, 'truth': '아니 선생님하고 어떻게 이야기가 됐길래 학습 종료가 안 돼요?', 'hypothesis': '아니, 선생님하고 어떻게 이야기가 됐길래 학습 종료가 안 돼요?', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0014.wav', 'duration': 2.268, 'latency': 0.884978099988075, 'rtf': 0.3902019841217262, 'wer': 0.6666666666666666, 'cer': 0.06666666666666667, 'truth': '알아보고 처리해 드리겠습니다.', 'hypothesis': '알아보고 처리해드리겠습니다.', 'status': 'success', 'error_msg': ''}, {'file': 'S00000365_0015.wav', 'duration': 8.023, 'latency': 2.184603600006085, 'rtf': 0.2722926087506026, 'wer':  ...

# %%
# 결과 분석
if results:
    df = pd.DataFrame(results)
    success_df = df[df['status'] == 'success']

    print("\n=== STT 성능 평가 결과 ===")
    print(f"총 시도: {len(df)} | 성공: {len(success_df)} | 실패: {len(df) - len(success_df)}")

    if not success_df.empty:
        print("-" * 40)
        print(f"1. 평균 변환 시간 : {success_df['latency'].mean():.4f} 초")
        print(f"2. p95 변환 시간  : {success_df['latency'].quantile(0.95):.4f} 초")
        print(f"3. RTF (평균)     : {success_df['rtf'].mean():.4f}")
        print(f"4. WER (단어 오류): {success_df['wer'].mean():.4f}")
        print(f"5. CER (음절 오류): {success_df['cer'].mean():.4f}")
        print("-" * 40)
# Out:
# === STT 성능 평가 결과 ===
# 총 시도: 321 | 성공: 321 | 실패: 0
# ----------------------------------------
# 1. 평균 변환 시간 : 1.2313 초
# 2. p95 변환 시간  : 2.3645 초
# 3. RTF (평균)     : 0.3964
# 4. WER (단어 오류): 0.2576
# 5. CER (음절 오류): 0.1167
# ----------------------------------------
